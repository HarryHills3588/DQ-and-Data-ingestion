# %%
import pandas as pd
import numpy as np
import os 
from pathlib import Path

DATA_PATH = Path(os.getcwd()).parent.parent.joinpath('data','employee_data.csv')
df = pd.read_csv(DATA_PATH)
df
# Out:
#      Employee Id              Name  Age   Department Date of Joining  \
# 0           1472  Stephen Cummings   36        Sales      2015-01-01
# 1           3617     Jessica Yoder   45    Marketing      01/01/2017
# 2           5264    Eric Zimmerman   44      Support      2023-01-01
# 3           4927       Scott Ellis   47  Development      2024-01-01
# 4           9332     Kathryn Jones   45   Operations      2019-01-01
# ..           ...               ...  ...          ...             ...
# 730         9473      Ricky Galvan   47      Support      2011/01/01
# 731         9849     Glenda Martin   43      Support      2018-01-01
# 732         9244     Jeanne Thomas   57          Sls      2010-01-01
# 733         6096      Jodi Donovan   52  Development      01-01-2021
# 734         8331       Gary Morris   48  Development      2016-01-01
#
#      Years of Experience  Country    Salary Performance Rating  Total Sales  \
# ...

# %%
df.dtypes
# Out:
# Employee Id              int64
# Name                    object
# Age                      int64
# Department              object
# Date of Joining         object
# Years of Experience      int64
# Country                 object
# Salary                 float64
# Performance Rating      object
# Total Sales              int64
# Support Rating           int64
# dtype: object

# %%
df['Performance Rating'].unique()
# Out:
# array(['3', '5', '2', '4', '1', 'Medium', 'High Performer', 'Medium High',
#        'Medium Low', 'Low Performer'], dtype=object)

# %%
df[df.isna().any(axis=1)].to_dict()
# Out:
# {'Employee Id': {2: 5264,
#   10: 7556,
#   19: 3414,
#   26: 4330,
#   49: 2583,
#   61: 3756,
#   68: 7164,
#   72: 1091,
#   113: 8955,
#   117: 4996,
#   122: 3340,
#   123: 4385,
#   124: 6087,
#   156: 8635,
#   167: 1205,
#   199: 7342,
#   205: 5123,
#   212: 3036,
#   213: 4925,
#   219: 6932,
#   233: 1129,
#   242: 6232,
#   249: 6258,
#   268: 5112,
#   272: 5649,
#   287: 2878,
#   289: 7965,
#   293: 1573,
#   305: 1190,
#   306: 4672,
#   315: 1784,
#   321: 2835,
#   344: 2966,
#   389: 8121,
#   434: 1763,
#   442: 5937,
#   447: 4366,
#   487: 4115,
#   498: 4674,
#   504: 1581,
#   511: 1054,
#   532: 7599,
#   540: 4513,
#   550: 8157,
#   553: 1828,
#   577: 3371,
#   628: 5620,
#   635: 5067,
#   636: 4966,
#   637: 7679,
#   658: 3043,
#   659: 2504,
#   660: 6325,
#   688: 3932,
#   695: 9898,
#   706: 8157,
#   708: 7599,
#   726: 1573},
#  'Name': {2: 'Eric Zimmerman',
#   10: nan,
#   19: nan,
#   26: nan,
#   49: 'James Scott',
#   61: 'Meagan Wilkins',
# ...

# %%
df.columns
# Out:
# Index(['Employee Id', 'Name', 'Age', 'Department', 'Date of Joining',
#        'Years of Experience', 'Country', 'Salary', 'Performance Rating',
#        'Total Sales', 'Support Rating'],
#       dtype='object')
